# %% [markdown]
# ## Mostrar la fecha de hoy
# En la celda a continuación, agregue el código para mostrar la fecha de hoy. Recuerda que puedes usar el dateobjeto de la datetimebiblioteca para acceder a la información del calendario.

# %%
from datetime import date
print(date.today())
# Out:
# 2023-03-12

# %% [markdown]
# ## Construye un convertidor de unidades,
# Ahora es el momento de centrar su atención en la segunda utilidad, la conversión de parsecs a años luz. Un parsec son 3,26 años luz, por lo que multiplicarás los parsecs por ese valor para determinar los años luz.
#
# Cree una variable llamada parsecsy configúrela en 11. Luego agregue el código para realizar el cálculo apropiado y almacene el resultado en una variable llamada lightyears. Finalmente, imprima el resultado en la pantalla para que muestre un mensaje similar al siguiente:
#
# "11 parsecs son ___ años luz"

# %%
parsecs = 11
producto = parsecs * 3.26
print(str(parsecs) + " parsecs son igual a: " + str(producto) + " Años luz")
print(type(producto))
# Out:
# 11 parsecs son igual a: 35.86 Años luz
# <class 'float'>

# %% [markdown]
# # Entrada de la línea de comandos
# Al iniciar un programa mediante python3, se le asigna el nombre del archivo que se va a iniciar. También puede asignarle un conjunto de argumentos: datos a los que el programa tendrá acceso al ejecutarse. Este es el aspecto que puede tener:

# %%
#python3 backup.py 2023-01-01
#Consola

# %% [markdown]
# ![image.png](attachment:image.png)
# #Se ejecuta el programa desde terminal
# ![image.png](attachment:image-2.png)
